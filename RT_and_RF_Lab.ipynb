# %% [markdown]
# <a href="https://colab.research.google.com/github/weisses1/swcolabfiles/blob/main/RT_and_RF_Lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Part 1 - Decision Trees

# %% [markdown]
# ### Step 1 - Load Data

# %% [markdown]
# The *adult_train.csv* file is the training dataset. Run the following code cell to load the dataset.

# %%
import pandas as pd
adult_train_path = r'https://raw.githubusercontent.com/ncrowder/python/refs/heads/main/decision_trees/adult_train.csv'
df = pd.read_csv(adult_train_path)
df.head()
# Out:
#    Age WorkClass  Fnlwgt     Education  EducationNum       MaritalStatus  \
# 0   20   Private   30035    Assoc-acdm            12       Never-married
# 1   22   Private  141297  Some-college            10       Never-married
# 2   63   Private  440607     Preschool             1  Married-civ-spouse
# 3   32   Private  165949     Bachelors            13            Divorced
# 4   36   Private  139743  Some-college            10             Widowed
#
#           Occupation   Relationship   Race     Sex  CapitalGain  CapitalLoss  \
# 0              Sales      Own-child  White  Female            0            0
# 1       Tech-support      Own-child  White    Male            0            0
# 2     Prof-specialty        Husband  Other    Male            0            0
# 3  Machine-op-inspct  Not-in-family  White  Female            0         1590
# 4     Prof-specialty      Own-child  White  Female            0            0
#
#    HoursPerWeek  NativeCountry  Label
# 0            40  United-States  <=50K
# 1            40  United-States  <=50K
# 2            30         Mexico  <=50K
# 3            42  United-States  <=50K
# 4            40  United-States  <=50K

# %% [markdown]
# ### Step 2 - Dataset Info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15016 entries, 0 to 15015
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Age            15016 non-null  int64
#  1   WorkClass      15016 non-null  object
#  2   Fnlwgt         15016 non-null  int64
#  3   Education      15016 non-null  object
#  4   EducationNum   15016 non-null  int64
#  5   MaritalStatus  15016 non-null  object
#  6   Occupation     15016 non-null  object
#  7   Relationship   15016 non-null  object
#  8   Race           15016 non-null  object
#  9   Sex            15016 non-null  object
#  10  CapitalGain    15016 non-null  int64
#  11  CapitalLoss    15016 non-null  int64
#  12  HoursPerWeek   15016 non-null  int64
#  13  NativeCountry  15016 non-null  object
#  14  Label          15016 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 1.7+ MB

# %%
df.select_dtypes('object').describe()
# Out:
#        WorkClass Education       MaritalStatus       Occupation Relationship  \
# count      15016     15016               15016            15016        15016
# unique         7        16                   7               14            6
# top      Private   HS-grad  Married-civ-spouse  Exec-managerial      Husband
# freq       10694      4366                8864             2621         7870
#
#          Race    Sex  NativeCountry  Label
# count   15016  15016          15016  15016
# unique      5      2             41      2
# top     White   Male  United-States  <=50K
# freq    13126  10980          13803   7508

# %%
df.describe()
# Out:
#                 Age        Fnlwgt  EducationNum   CapitalGain   CapitalLoss  \
# count  15016.000000  1.501600e+04  15016.000000  15016.000000  15016.000000
# mean      40.200386  1.884496e+05     10.611082   2045.919219    121.227158
# std       12.432960  1.044355e+05      2.580166  10368.504403    474.990588
# min       17.000000  1.487800e+04      1.000000      0.000000      0.000000
# 25%       31.000000  1.174752e+05      9.000000      0.000000      0.000000
# 50%       40.000000  1.769920e+05     10.000000      0.000000      0.000000
# 75%       49.000000  2.356915e+05     13.000000      0.000000      0.000000
# max       90.000000  1.268339e+06     16.000000  99999.000000   3900.000000
#
#        HoursPerWeek
# count  15016.000000
# mean      42.599760
# std       11.810685
# min        1.000000
# 25%       40.000000
# 50%       40.000000
# 75%       50.000000
# max       99.000000

# %% [markdown]
# ### Step 3 - Preparing the Features

# %% [markdown]
# Using subject matter expertise to choose features is critical in crafting the most valuable machine models. In the case of the *Adult Census* dataset, you can select features based on knowledge of the US economy. For example, certain factors (e.g., level of education) are highly associated with higher income levels.
#
# The first model will be based on the hypothesis that older, more educated citizens in certain occupations have higher incomes by using the following features: *Age*, *EducationNum*, *Occupation*, and *HoursPerWeek*. As the *Occupation* feature is categorical, it will need to be one-hot encoded.

# %%
x = ['Age','EducationNum', 'Occupation', 'HoursPerWeek']
df_x = pd.get_dummies(df[x], columns=['Occupation'])
df_x.head()
# Out:
#    Age  EducationNum  HoursPerWeek  Occupation_Adm-clerical  \
# 0   20            12            40                    False
# 1   22            10            40                    False
# 2   63             1            30                    False
# 3   32            13            42                    False
# 4   36            10            40                    False
#
#    Occupation_Armed-Forces  Occupation_Craft-repair  \
# 0                    False                    False
# 1                    False                    False
# 2                    False                    False
# 3                    False                    False
# 4                    False                    False
#
#    Occupation_Exec-managerial  Occupation_Farming-fishing  \
# 0                       False                       False
# 1                       False                       False
# 2                       False                       False
# 3                       False                       False
# 4                       False                       False
#
#    Occupation_Handlers-cleaners  Occupation_Machine-op-inspct  \
# 0                         False                         False
# 1                         False                         False
# 2                         False                         False
# 3                         False                          True
# 4                         False                         False
#
#    Occupation_Other-service  Occupation_Priv-house-serv  \
# 0                     False                       False
# 1                     False                       False
# 2                     False                       False
# 3                     False                       False
# 4                     False                       False
#
#    Occupation_Prof-specialty  Occupation_Protective-serv  Occupation_Sales  \
# 0                      False                       False              True
# 1                      False                       False             False
# 2                       True                       False             False
# 3                      False                       False             False
# 4                       True                       False             False
#
#    Occupation_Tech-support  Occupation_Transport-moving
# 0                    False                        False
# 1                     True                        False
# 2                    False                        False
# 3                    False                        False
# 4                    False                        False

# %% [markdown]
# ### Step 4 - Preparing the Labels

# %% [markdown]
# The dataset labels are strings that the classifer will encode "under the hood" anyway, but we do it here manually to demonstrate.

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_encoder = LabelEncoder()
df_y = label_encoder.fit_transform(df['Label'])
print(label_encoder.classes_)
print(df_y)
# Out:
# ['<=50K' '>50K']
# [0 0 0 ... 1 1 1]

# %% [markdown]
# ### Step 5 - Training Your First Model

# %% [markdown]
# With the features and labels prepped, it is time to train your first model. The *min_samples_leaf* hyperparameter will be set to control the tree size. The *random_state* will also be set to a common value to ensure reproducibility. Type the following code into the blank code cell in your lab notebook and run it to produce the results.

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier(min_samples_leaf = .05, max_depth = 3, random_state=123)
#min_samples_leaf typically always get set at .05 of the data to keep things concise
#ways to limit tree- max_depth will only let the tree branch down what you set.
dt.fit(df_x,df_y)
# Out:
# DecisionTreeClassifier(max_depth=3, min_samples_leaf=0.05, random_state=123)

# %% [markdown]
# ### Step 6 - Visualizing Your First Model

# %% [markdown]
# One of the primary benefits of decision trees is that they are easily interpreted when visualized.

# %%
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree
plt.figure(figsize=(12,12))
plot_tree(dt,feature_names=df_x.columns,class_names=label_encoder.classes_, filled=True);
#gini- likelihood of a misclassified sample if one was pulled out randomly

# %% [markdown]
# ### Step 7 - Preparing Features for a 2nd Model

# %% [markdown]
# We may know that married couples in the US tend to have high incomes, and gender is also highly associated with income in the US. You can train a 2nd model to explore this refined hypothesis by adding the *MaritalStatus* and *Sex* features.

# %%
x = ['Age','EducationNum', 'Occupation', 'HoursPerWeek', 'Sex', 'MaritalStatus']
x_cat = ['MaritalStatus','Occupation','Sex']
df_x = pd.get_dummies(df[x], prefix = x_cat, columns = x_cat)
df_x.head()
# Out:
#    Age  EducationNum  HoursPerWeek  MaritalStatus_Divorced  \
# 0   20            12            40                   False
# 1   22            10            40                   False
# 2   63             1            30                   False
# 3   32            13            42                    True
# 4   36            10            40                   False
#
#    MaritalStatus_Married-AF-spouse  MaritalStatus_Married-civ-spouse  \
# 0                            False                             False
# 1                            False                             False
# 2                            False                              True
# 3                            False                             False
# 4                            False                             False
#
#    MaritalStatus_Married-spouse-absent  MaritalStatus_Never-married  \
# 0                                False                         True
# 1                                False                         True
# 2                                False                        False
# 3                                False                        False
# 4                                False                        False
#
#    MaritalStatus_Separated  MaritalStatus_Widowed  ...  \
# 0                    False                  False  ...
# 1                    False                  False  ...
# 2                    False                  False  ...
# 3                    False                  False  ...
# 4                    False                   True  ...
#
#    Occupation_Machine-op-inspct  Occupation_Other-service  \
# 0                         False                     False
# 1                         False                     False
# 2                         False                     False
# 3                          True                     False
# 4                         False                     False
#
#    Occupation_Priv-house-serv  Occupation_Prof-specialty  \
# 0                       False                      False
# 1                       False                      False
# 2                       False                       True
# 3                       False                      False
# 4                       False                       True
#
#    Occupation_Protective-serv  Occupation_Sales  Occupation_Tech-support  \
# 0                       False              True                    False
# 1                       False             False                     True
# 2                       False             False                    False
# 3                       False             False                    False
# 4                       False             False                    False
#
#    Occupation_Transport-moving  Sex_Female  Sex_Male
# 0                        False        True     False
# 1                        False       False      True
# 2                        False       False      True
# 3                        False        True     False
# 4                        False        True     False
#
# [5 rows x 26 columns]

# %% [markdown]
# ### Step 8 - Training a 2nd Model

# %% [markdown]
# Using the same parameters as above to make a comparison.

# %%
dt2 = DecisionTreeClassifier(min_samples_leaf = .05, max_depth = 4, random_state=123)
dt2.fit(df_x,df_y)
# Out:
# DecisionTreeClassifier(max_depth=4, min_samples_leaf=0.05, random_state=123)

# %% [markdown]
# ### Step 9 - Visualizing the 2nd Model

# %%
plt.figure(figsize=(12,12))
plot_tree(dt2,feature_names=df_x.columns,class_names=label_encoder.classes_, filled=True);

# %% [markdown]
# # Part 2 - Random Forests

# %% [markdown]
# ### Step 1 - Prepare the Features

# %% [markdown]
# We will now expand the working hypotheses to include the *Race*, *CapitalGain*, and *CapitalLoss* features. The intuition is that *Race* is associated with income in the US economy, and the *CapitalGain* and *CapitalLoss* features are also associated with income.

# %%
x = ['Age','EducationNum', 'Occupation', 'HoursPerWeek', 'Sex', 'MaritalStatus', 'Race', 'CapitalGain','CapitalLoss']
x_cat = ['MaritalStatus','Occupation','Sex','Race']
df_x = pd.get_dummies(df[x], prefix = x_cat, columns = x_cat)
df_x.head()
#random forests takes a random value for something, and then the value gets put back and could possibly be chosen again (bootstrapping)
# Out:
#    Age  EducationNum  HoursPerWeek  CapitalGain  CapitalLoss  \
# 0   20            12            40            0            0
# 1   22            10            40            0            0
# 2   63             1            30            0            0
# 3   32            13            42            0         1590
# 4   36            10            40            0            0
#
#    MaritalStatus_Divorced  MaritalStatus_Married-AF-spouse  \
# 0                   False                            False
# 1                   False                            False
# 2                   False                            False
# 3                    True                            False
# 4                   False                            False
#
#    MaritalStatus_Married-civ-spouse  MaritalStatus_Married-spouse-absent  \
# 0                             False                                False
# 1                             False                                False
# 2                              True                                False
# 3                             False                                False
# 4                             False                                False
#
#    MaritalStatus_Never-married  ...  Occupation_Sales  \
# 0                         True  ...              True
# 1                         True  ...             False
# 2                        False  ...             False
# 3                        False  ...             False
# 4                        False  ...             False
#
#    Occupation_Tech-support  Occupation_Transport-moving  Sex_Female  Sex_Male  \
# 0                    False                        False        True     False
# 1                     True                        False       False      True
# 2                    False                        False       False      True
# 3                    False                        False        True     False
# 4                    False                        False        True     False
#
#    Race_Amer-Indian-Eskimo  Race_Asian-Pac-Islander  Race_Black  Race_Other  \
# 0                    False                    False       False       False
# 1                    False                    False       False       False
# 2                    False                    False       False        True
# 3                    False                    False       False       False
# 4                    False                    False       False       False
#
#    Race_White
# 0        True
# 1        True
# 2       False
# 3        True
# 4        True
#
# [5 rows x 33 columns]

# %% [markdown]
# ### Step 2 - Preparing the Labels

# %% [markdown]
# As with Part 1, we'll manually encode the target.

# %%
label_encoder = LabelEncoder()
df_y = label_encoder.fit_transform(df['Label'])
print(label_encoder.classes_)
print(df_y)
# Out:
# ['<=50K' '>50K']
# [0 0 0 ... 1 1 1]

# %% [markdown]
# ### Step 3 - Train the Random Forest

# %% [markdown]
# As you have certainly noticed by now, the *scikit-learn* library was designed to enable repeating coding patterns regardless of the machine learning algorithm you use. For example, the *fit()* method is the same across the *DecisionTreeClassifier* and *RandomForestClassifer* classes.

# %%
from sklearn.ensemble import RandomForestClassifier as rfc

# %%
rf = rfc(n_estimators = 200, oob_score=True, n_jobs = 1, random_state = 123) #200 trees, not limited here by max_depth or min_samples_leaf.
#any tree has OOB (out of box)
rf.fit(df_x,df_y)
print(f'Estimated accuracy with OOB data: {rf.oob_score_:.4f}')
print(f'Training data accuracy: {rf.score(df_x,df_y):.4f}') #score on the training set, we should use a test set here if we wanted a more honest appraisal
# Out:
# Estimated accuracy with OOB data: 0.8115
# Training data accuracy: 0.9638

# %% [markdown]
# ### Step 4 - Get OOB Predictions

# %% [markdown]
# OOB means "out of box" and it represents those pieces of data not selected for a particular tree. Think of OOB data as representing the unkownable future. Analyzing the predictive performance of a *RandomForestClassifier* in terms of OOB allows for estimating the quality of the model's future predictions. The first step is to build the predicted OOB labels.

# %%
oobs = pd.DataFrame(rf.oob_decision_function_, columns = label_encoder.classes_)
oobs['Label'] = 0
oobs.loc[oobs['>50K'] > .5, 'Label'] = 1
oobs
# Out:
#           <=50K      >50K  Label
# 0      1.000000  0.000000      0
# 1      0.971014  0.028986      0
# 2      0.605263  0.394737      0
# 3      0.815972  0.184028      0
# 4      0.945946  0.054054      0
# ...         ...       ...    ...
# 15011  0.891228  0.108772      0
# 15012  0.130128  0.869872      1
# 15013  0.007143  0.992857      1
# 15014  0.259740  0.740260      1
# 15015  0.000000  1.000000      1
#
# [15016 rows x 3 columns]

# %% [markdown]
# ### Step 5 - Analyzing the OOB Predictions

# %% [markdown]
# Using a *confusion matrix* to analyze OOB predictions gives you insights into how your *RandomForestClassifier* is performing. The confusion matrix allows you answer many questions about the nature of model predictions.

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
cm = confusion_matrix(df_y, oobs['Label'])
cmd = ConfusionMatrixDisplay(cm, display_labels = label_encoder.classes_)
cmd.plot()
#shows how the labels created fall

# %% [markdown]
# ## Part 3 - Feature Importance and Engineering

# %% [markdown]
# ### Step 1 - Engineer the *Female* Feature

# %% [markdown]
# You have one-hot encoded the *Sex* categorical feature. This encoding produced two binary features - *Sex_Female* and *Sex_Male*. While these two features are reasonable for use in machine learning, they are not optimal. A better approach would be to engineer a single feature based on one of the categories. For example, a binary *Female* feature.

# %%
df['Female'] = df['Sex'].map({'Female':1, 'Male':0})
df.head()
# Out:
#    Age WorkClass  Fnlwgt     Education  EducationNum       MaritalStatus  \
# 0   20   Private   30035    Assoc-acdm            12       Never-married
# 1   22   Private  141297  Some-college            10       Never-married
# 2   63   Private  440607     Preschool             1  Married-civ-spouse
# 3   32   Private  165949     Bachelors            13            Divorced
# 4   36   Private  139743  Some-college            10             Widowed
#
#           Occupation   Relationship   Race     Sex  CapitalGain  CapitalLoss  \
# 0              Sales      Own-child  White  Female            0            0
# 1       Tech-support      Own-child  White    Male            0            0
# 2     Prof-specialty        Husband  Other    Male            0            0
# 3  Machine-op-inspct  Not-in-family  White  Female            0         1590
# 4     Prof-specialty      Own-child  White  Female            0            0
#
#    HoursPerWeek  NativeCountry  Label  Female
# 0            40  United-States  <=50K       1
# 1            40  United-States  <=50K       0
# 2            30         Mexico  <=50K       0
# 3            42  United-States  <=50K       1
# 4            40  United-States  <=50K       1

# %% [markdown]
# ### Step 2 - Prepare the Features

# %% [markdown]
# The following code prepares the features. Unlike the previous part, the *Sex* feature no longer needs to be one-hot encoded because the new *Female* feature is already numeric.

# %%
x = ['Age','EducationNum', 'Occupation', 'HoursPerWeek', 'Female', 'MaritalStatus', 'Race', 'CapitalGain','CapitalLoss']
x_cat = ['MaritalStatus','Occupation','Race']
df_x = pd.get_dummies(df[x], prefix = x_cat, columns = x_cat)
df_x.head()
# Out:
#    Age  EducationNum  HoursPerWeek  Female  CapitalGain  CapitalLoss  \
# 0   20            12            40       1            0            0
# 1   22            10            40       0            0            0
# 2   63             1            30       0            0            0
# 3   32            13            42       1            0         1590
# 4   36            10            40       1            0            0
#
#    MaritalStatus_Divorced  MaritalStatus_Married-AF-spouse  \
# 0                   False                            False
# 1                   False                            False
# 2                   False                            False
# 3                    True                            False
# 4                   False                            False
#
#    MaritalStatus_Married-civ-spouse  MaritalStatus_Married-spouse-absent  ...  \
# 0                             False                                False  ...
# 1                             False                                False  ...
# 2                              True                                False  ...
# 3                             False                                False  ...
# 4                             False                                False  ...
#
#    Occupation_Prof-specialty  Occupation_Protective-serv  Occupation_Sales  \
# 0                      False                       False              True
# 1                      False                       False             False
# 2                       True                       False             False
# 3                      False                       False             False
# 4                       True                       False             False
#
#    Occupation_Tech-support  Occupation_Transport-moving  \
# 0                    False                        False
# 1                     True                        False
# 2                    False                        False
# 3                    False                        False
# 4                    False                        False
#
#    Race_Amer-Indian-Eskimo  Race_Asian-Pac-Islander  Race_Black  Race_Other  \
# 0                    False                    False       False       False
# 1                    False                    False       False       False
# 2                    False                    False       False        True
# 3                    False                    False       False       False
# 4                    False                    False       False       False
#
#    Race_White
# 0        True
# 1        True
# 2       False
# 3        True
# 4        True
#
# [5 rows x 32 columns]

# %% [markdown]
# ### Step 3 - Preparing the Labels

# %%
label_encoder = LabelEncoder()
df_y = label_encoder.fit_transform(df['Label'])
print(label_encoder.classes_)
print(df_y)
# Out:
# ['<=50K' '>50K']
# [0 0 0 ... 1 1 1]

# %% [markdown]
# ### Step 4 - Train the Random Forest

# %%
rf = rfc(n_estimators = 200, oob_score=True, n_jobs = -1, random_state = 123)
rf.fit(df_x,df_y)
print(f'Estimated accuracy with OOB data: {rf.oob_score_:.4f}')
print(f'Training data accuracy: {rf.score(df_x,df_y):.4f}') # score on the training set, we should use a test set here if we wanted a more honest appraisal
# Out:
# Estimated accuracy with OOB data: 0.8127
# Training data accuracy: 0.9638

# %% [markdown]
# ### Step 5 - Feature Importance

# %% [markdown]
# As discussed in lecture, permutation importance is one way to determine feature importance.  It is rather compute-intensive.

# %%
from sklearn.inspection import permutation_importance

# %%
imp = permutation_importance(rf, df_x, df_y, n_repeats = 5, n_jobs = 1, random_state = 123)
sorted_idx = imp.importances_mean.argsort()
importance_dict = {'Feature': df_x.columns.values[sorted_idx], 'Importance': imp.importances_mean[sorted_idx]}
imp_df = pd.DataFrame(importance_dict)
imp_df.sort_values('Importance',ascending=False)
#the higher the number, the higher the drop in accuracy
# Out:
#                                 Feature  Importance
# 31                                  Age    0.148628
# 30                         EducationNum    0.140290
# 29     MaritalStatus_Married-civ-spouse    0.122616
# 28                         HoursPerWeek    0.104768
# 27                          CapitalGain    0.066103
# 26                               Female    0.045645
# 25           Occupation_Exec-managerial    0.027957
# 24            Occupation_Prof-specialty    0.024627
# 23          MaritalStatus_Never-married    0.022216
# 22                          CapitalLoss    0.018487
# 21              Occupation_Craft-repair    0.016023
# 20                     Occupation_Sales    0.012267
# 19             Occupation_Other-service    0.012254
# 18                           Race_White    0.011348
# 17               MaritalStatus_Divorced    0.009430
# 16              Occupation_Adm-clerical    0.009297
# 15          Occupation_Transport-moving    0.008737
# 14                           Race_Black    0.006846
# 13         Occupation_Machine-op-inspct    0.006420
# 12           Occupation_Farming-fishing    0.005967
# 11         Occupation_Handlers-cleaners    0.004928
# 10              Occupation_Tech-support    0.004395
# 9            Occupation_Protective-serv    0.003823
# 8               Race_Asian-Pac-Islander    0.002944
# 7                 MaritalStatus_Widowed    0.001838
# 6               MaritalStatus_Separated    0.001039
# 5               Race_Amer-Indian-Eskimo    0.000759
# 4   MaritalStatus_Married-spouse-absent    0.000559
# 3       MaritalStatus_Married-AF-spouse    0.000533
# 2                            Race_Other    0.000253
# 1            Occupation_Priv-house-serv    0.000040
# 0               Occupation_Armed-Forces    0.000000

# %% [markdown]
# # Part 4 - Model Testing

# %% [markdown]
# ### Step 1 - Load Test Data

# %%
df_test_path = r'https://raw.githubusercontent.com/ncrowder/python/refs/heads/main/decision_trees/adult_test.csv'
df_test = pd.read_csv(df_test_path)
df_test.head()
# Out:
#    Age WorkClass  Fnlwgt     Education  EducationNum       MaritalStatus  \
# 0   32   Private  185820     Bachelors            13       Never-married
# 1   34   Private  122749  Some-college            10  Married-civ-spouse
# 2   20   Private  117476  Some-college            10       Never-married
# 3   36   Private  185692       7th-8th             4  Married-civ-spouse
# 4   73   Private   88594       HS-grad             9            Divorced
#
#           Occupation   Relationship   Race     Sex  CapitalGain  CapitalLoss  \
# 0     Prof-specialty  Not-in-family  Black  Female            0            0
# 1  Handlers-cleaners        Husband  White    Male            0            0
# 2  Handlers-cleaners      Own-child  White    Male            0            0
# 3    Farming-fishing        Husband  White    Male            0            0
# 4    Exec-managerial  Not-in-family  White  Female            0            0
#
#    HoursPerWeek    NativeCountry  Label
# 0            40  Trinadad&Tobago  <=50K
# 1            32  Trinadad&Tobago  <=50K
# 2            40  Trinadad&Tobago  <=50K
# 3            35  Trinadad&Tobago  <=50K
# 4            35  Trinadad&Tobago  <=50K

# %% [markdown]
# ### Step 2 - Prepare the Test Data Features

# %% [markdown]
# A trained machine learning model requires the test *DataFrame* to have columns that match those used to train the model. Any data cleaning or feature engineering performed on the training *DataFrame* has to be applied to the test dataset.

# %%
df_test['Female'] = df_test['Sex'].map({'Female':1, 'Male':0})
df_test_x = pd.get_dummies(df_test[x], prefix = x_cat, columns = x_cat)
df_test_x
# Out:
#       Age  EducationNum  HoursPerWeek  Female  CapitalGain  CapitalLoss  \
# 0      32            13            40       1            0            0
# 1      34            10            32       0            0            0
# 2      20            10            40       0            0            0
# 3      36             4            35       0            0            0
# 4      73             9            35       1            0            0
# ...   ...           ...           ...     ...          ...          ...
# 7395   28            15            50       0            0            0
# 7396   56             9            40       0            0            0
# 7397   41            15            45       0            0            0
# 7398   37            14            40       0            0            0
# 7399   48            13            38       1            0            0
#
#       MaritalStatus_Divorced  MaritalStatus_Married-AF-spouse  \
# 0                      False                            False
# 1                      False                            False
# 2                      False                            False
# 3                      False                            False
# 4                       True                            False
# ...                      ...                              ...
# 7395                   False                            False
# 7396                   False                            False
# 7397                   False                            False
# 7398                   False                            False
# 7399                   False                            False
#
#       MaritalStatus_Married-civ-spouse  MaritalStatus_Married-spouse-absent  \
# 0                                False                                False
# 1                                 True                                False
# 2                                False                                False
# 3                                 True                                False
# 4                                False                                False
# ...                                ...                                  ...
# 7395                              True                                False
# 7396                              True                                False
# 7397                              True                                False
# 7398                              True                                False
# 7399                             False                                False
#
#       ...  Occupation_Prof-specialty  Occupation_Protective-serv  \
# 0     ...                       True                       False
# 1     ...                      False                       False
# 2     ...                      False                       False
# 3     ...                      False                       False
# 4     ...                      False                       False
# ...   ...                        ...                         ...
# 7395  ...                       True                       False
# 7396  ...                      False                       False
# 7397  ...                       True                       False
# 7398  ...                      False                       False
# 7399  ...                      False                       False
#
#       Occupation_Sales  Occupation_Tech-support  Occupation_Transport-moving  \
# 0                False                    False                        False
# 1                False                    False                        False
# 2                False                    False                        False
# 3                False                    False                        False
# 4                False                    False                        False
# ...                ...                      ...                          ...
# 7395             False                    False                        False
# 7396             False                    False                        False
# 7397             False                    False                        False
# 7398             False                    False                        False
# 7399              True                    False                        False
#
#       Race_Amer-Indian-Eskimo  Race_Asian-Pac-Islander  Race_Black  \
# 0                       False                    False        True
# 1                       False                    False       False
# 2                       False                    False       False
# 3                       False                    False       False
# 4                       False                    False       False
# ...                       ...                      ...         ...
# 7395                    False                    False       False
# 7396                    False                    False       False
# 7397                    False                    False       False
# 7398                    False                    False       False
# 7399                    False                    False       False
#
#       Race_Other  Race_White
# 0          False       False
# 1          False        True
# 2          False        True
# 3          False        True
# 4          False        True
# ...          ...         ...
# 7395       False        True
# 7396       False        True
# 7397       False        True
# 7398       False        True
# 7399       False        True
#
# [7400 rows x 32 columns]

# %% [markdown]
# ### Step 3 - Preparing the Test Labels

# %% [markdown]
# Now we'll prepare the test set labels to match the training dataset's labels as before. The easiest way to achieve this is to use the existing *LabelEncoder* object created previously using the *transform()* method instead of *fit_transform()*.

# %%
df_test_y = label_encoder.transform(df_test['Label'])

# %% [markdown]
# ### Step 4 - Making Predictions

# %% [markdown]
# The *RandomForestClassifier* offers the *predict()* method to make predictions for a dataset. In this case, predictions for the test dataset. Type the following code into the blank code cell in your lab notebook and run it to produce the results.

# %%
test_preds = rf.predict(df_test_x)

# %% [markdown]
# ### Step 5 - Evaluating the Model

# %% [markdown]
# As discussed during the lecture, the final step of any machine learning project is evaluating the model's predictive performance against the test data. The goal is to ascertain how likely the model is to meet business requirements in the future.

# %%
print(f'Test dataset accuracy: {rf.score(df_test_x, df_test_y): .4f}')
cm = confusion_matrix(df_test_y,test_preds)
cmd = ConfusionMatrixDisplay(cm,display_labels = label_encoder.classes_)
cmd.plot()
# Out:
# Test dataset accuracy:  0.8080

# %% [markdown]
# # Your Turn

# %% [markdown]
# Exercise #1: Take only the **top 10 features** according to permutation importance calculated previously on the *training set* and then retrain and refit a random forest (call it rf2).
#
# Then calculate the OOB accuracy as well as the accuracy on the test data set.
#
# What are the features for the 100th row of the test dataset and what is the prediction?  Is it accurate?

# %%
top_10 = imp_df.sort_values('Importance', ascending=False).head(10)
top_10
# Out:
#                              Feature  Importance
# 31                               Age    0.148628
# 30                      EducationNum    0.140290
# 29  MaritalStatus_Married-civ-spouse    0.122616
# 28                      HoursPerWeek    0.104768
# 27                       CapitalGain    0.066103
# 26                            Female    0.045645
# 25        Occupation_Exec-managerial    0.027957
# 24         Occupation_Prof-specialty    0.024627
# 23       MaritalStatus_Never-married    0.022216
# 22                       CapitalLoss    0.018487

# %%
df['Female'] = df['Sex'].map({'Female':1, 'Male':0})
df.head()
# Out:
#    Age WorkClass  Fnlwgt     Education  EducationNum       MaritalStatus  \
# 0   20   Private   30035    Assoc-acdm            12       Never-married
# 1   22   Private  141297  Some-college            10       Never-married
# 2   63   Private  440607     Preschool             1  Married-civ-spouse
# 3   32   Private  165949     Bachelors            13            Divorced
# 4   36   Private  139743  Some-college            10             Widowed
#
#           Occupation   Relationship   Race     Sex  CapitalGain  CapitalLoss  \
# 0              Sales      Own-child  White  Female            0            0
# 1       Tech-support      Own-child  White    Male            0            0
# 2     Prof-specialty        Husband  Other    Male            0            0
# 3  Machine-op-inspct  Not-in-family  White  Female            0         1590
# 4     Prof-specialty      Own-child  White  Female            0            0
#
#    HoursPerWeek  NativeCountry  Label  Female
# 0            40  United-States  <=50K       1
# 1            40  United-States  <=50K       0
# 2            30         Mexico  <=50K       0
# 3            42  United-States  <=50K       1
# 4            40  United-States  <=50K       1

# %%
x = ['Age','EducationNum', 'MaritalStatus', 'HoursPerWeek', 'CapitalGain', 'Female', 'Occupation','CapitalLoss']
x_cat = ['MaritalStatus','Occupation']
df_x = pd.get_dummies(df[x], prefix = x_cat, columns = x_cat)
df_x.head()
# Out:
#    Age  EducationNum  HoursPerWeek  CapitalGain  Female  CapitalLoss  \
# 0   20            12            40            0       1            0
# 1   22            10            40            0       0            0
# 2   63             1            30            0       0            0
# 3   32            13            42            0       1         1590
# 4   36            10            40            0       1            0
#
#    MaritalStatus_Divorced  MaritalStatus_Married-AF-spouse  \
# 0                   False                            False
# 1                   False                            False
# 2                   False                            False
# 3                    True                            False
# 4                   False                            False
#
#    MaritalStatus_Married-civ-spouse  MaritalStatus_Married-spouse-absent  ...  \
# 0                             False                                False  ...
# 1                             False                                False  ...
# 2                              True                                False  ...
# 3                             False                                False  ...
# 4                             False                                False  ...
#
#    Occupation_Farming-fishing  Occupation_Handlers-cleaners  \
# 0                       False                         False
# 1                       False                         False
# 2                       False                         False
# 3                       False                         False
# 4                       False                         False
#
#    Occupation_Machine-op-inspct  Occupation_Other-service  \
# 0                         False                     False
# 1                         False                     False
# 2                         False                     False
# 3                          True                     False
# 4                         False                     False
#
#    Occupation_Priv-house-serv  Occupation_Prof-specialty  \
# 0                       False                      False
# 1                       False                      False
# 2                       False                       True
# 3                       False                      False
# 4                       False                       True
#
#    Occupation_Protective-serv  Occupation_Sales  Occupation_Tech-support  \
# 0                       False              True                    False
# 1                       False             False                     True
# 2                       False             False                    False
# 3                       False             False                    False
# 4                       False             False                    False
#
#    Occupation_Transport-moving
# 0                        False
# 1                        False
# 2                        False
# 3                        False
# 4                        False
#
# [5 rows x 27 columns]

# %%
label_encoder = LabelEncoder()
df_y = label_encoder.fit_transform(df['Label'])
print(label_encoder.classes_)
print(df_y)
# Out:
# ['<=50K' '>50K']
# [0 0 0 ... 1 1 1]

# %%
rf2 = rfc(n_estimators = 200, oob_score=True, n_jobs = -1, random_state = 123)
rf2.fit(df_x,df_y)
print(f'Estimated accuracy with OOB data: {rf2.oob_score_:.4f}')
print(f'Training data accuracy: {rf2.score(df_x,df_y):.4f}')
# Out:
# Estimated accuracy with OOB data: 0.8124
# Training data accuracy: 0.9586

# %%
df_test['Female'] = df_test['Sex'].map({'Female':1, 'Male':0})
df_test_x = pd.get_dummies(df_test[x], prefix = x_cat, columns = x_cat)
df_test_x
# Out:
#       Age  EducationNum  HoursPerWeek  CapitalGain  Female  CapitalLoss  \
# 0      32            13            40            0       1            0
# 1      34            10            32            0       0            0
# 2      20            10            40            0       0            0
# 3      36             4            35            0       0            0
# 4      73             9            35            0       1            0
# ...   ...           ...           ...          ...     ...          ...
# 7395   28            15            50            0       0            0
# 7396   56             9            40            0       0            0
# 7397   41            15            45            0       0            0
# 7398   37            14            40            0       0            0
# 7399   48            13            38            0       1            0
#
#       MaritalStatus_Divorced  MaritalStatus_Married-AF-spouse  \
# 0                      False                            False
# 1                      False                            False
# 2                      False                            False
# 3                      False                            False
# 4                       True                            False
# ...                      ...                              ...
# 7395                   False                            False
# 7396                   False                            False
# 7397                   False                            False
# 7398                   False                            False
# 7399                   False                            False
#
#       MaritalStatus_Married-civ-spouse  MaritalStatus_Married-spouse-absent  \
# 0                                False                                False
# 1                                 True                                False
# 2                                False                                False
# 3                                 True                                False
# 4                                False                                False
# ...                                ...                                  ...
# 7395                              True                                False
# 7396                              True                                False
# 7397                              True                                False
# 7398                              True                                False
# 7399                             False                                False
#
#       ...  Occupation_Farming-fishing  Occupation_Handlers-cleaners  \
# 0     ...                       False                         False
# 1     ...                       False                          True
# 2     ...                       False                          True
# 3     ...                        True                         False
# 4     ...                       False                         False
# ...   ...                         ...                           ...
# 7395  ...                       False                         False
# 7396  ...                       False                         False
# 7397  ...                       False                         False
# 7398  ...                       False                         False
# 7399  ...                       False                         False
#
#       Occupation_Machine-op-inspct  Occupation_Other-service  \
# 0                            False                     False
# 1                            False                     False
# 2                            False                     False
# 3                            False                     False
# 4                            False                     False
# ...                            ...                       ...
# 7395                         False                     False
# 7396                         False                     False
# 7397                         False                     False
# 7398                         False                     False
# 7399                         False                     False
#
#       Occupation_Priv-house-serv  Occupation_Prof-specialty  \
# 0                          False                       True
# 1                          False                      False
# 2                          False                      False
# 3                          False                      False
# 4                          False                      False
# ...                          ...                        ...
# 7395                       False                       True
# 7396                       False                      False
# 7397                       False                       True
# 7398                       False                      False
# 7399                       False                      False
#
#       Occupation_Protective-serv  Occupation_Sales  Occupation_Tech-support  \
# 0                          False             False                    False
# 1                          False             False                    False
# 2                          False             False                    False
# 3                          False             False                    False
# 4                          False             False                    False
# ...                          ...               ...                      ...
# 7395                       False             False                    False
# 7396                       False             False                    False
# 7397                       False             False                    False
# 7398                       False             False                    False
# 7399                       False              True                    False
#
#       Occupation_Transport-moving
# 0                           False
# 1                           False
# 2                           False
# 3                           False
# 4                           False
# ...                           ...
# 7395                        False
# 7396                        False
# 7397                        False
# 7398                        False
# 7399                        False
#
# [7400 rows x 27 columns]

# %%
df_test_y = label_encoder.transform(df_test['Label'])

# %%
test_preds = rf2.predict(df_test_x)

# %%
oobs = pd.DataFrame(rf2.oob_decision_function_, columns = label_encoder.classes_)
oobs['Label'] = 0
oobs.loc[oobs['>50K'] > .5, 'Label'] = 1
oobs
# Out:
#           <=50K      >50K  Label
# 0      1.000000  0.000000      0
# 1      1.000000  0.000000      0
# 2      0.855263  0.144737      0
# 3      0.791667  0.208333      0
# 4      0.905405  0.094595      0
# ...         ...       ...    ...
# 15011  0.916667  0.083333      0
# 15012  0.191239  0.808761      1
# 15013  0.014286  0.985714      1
# 15014  0.194805  0.805195      1
# 15015  0.000000  1.000000      1
#
# [15016 rows x 3 columns]

# %%
print(f'Test dataset accuracy: {rf2.score(df_test_x, df_test_y): .4f}')
# Out:
# Test dataset accuracy:  0.8118

# %%
df_test_x.loc[99]
# Out:
# Age                                       44
# EducationNum                              10
# HoursPerWeek                              40
# CapitalGain                                0
# Female                                     0
# CapitalLoss                                0
# MaritalStatus_Divorced                 False
# MaritalStatus_Married-AF-spouse        False
# MaritalStatus_Married-civ-spouse        True
# MaritalStatus_Married-spouse-absent    False
# MaritalStatus_Never-married            False
# MaritalStatus_Separated                False
# MaritalStatus_Widowed                  False
# Occupation_Adm-clerical                False
# Occupation_Armed-Forces                False
# Occupation_Craft-repair                 True
# Occupation_Exec-managerial             False
# Occupation_Farming-fishing             False
# Occupation_Handlers-cleaners           False
# Occupation_Machine-op-inspct           False
# Occupation_Other-service               False
# Occupation_Priv-house-serv             False
# Occupation_Prof-specialty              False
# Occupation_Protective-serv             False
# Occupation_Sales                       False
# Occupation_Tech-support                False
# Occupation_Transport-moving            False
# Name: 99, dtype: object

# %%
test_preds[99]
# Out:
# np.int64(0)

# %%
df_test_y[99]
# Out:
# np.int64(0)

# %%
test_preds[99] == df_test_y[99]
# Out:
# np.True_

# %% [markdown]
# Exercise #2: combine the test and train datasets together (maybe use *concat*) and perform a standard train_test split at the typical 80:20 ratio.  Then train a random forest on the features from parts 3 and 4 (call it rf3).
#
# Then calculate the OOB accuracy as well as the accuracy on the test data set.
#
# What are the features for the 100th row of the test dataset and what is the prediction?  Is it accurate?

# %%
df_total_x = pd.concat([df_x, df_test_x], axis=0)

# %%
dfy = pd.DataFrame(df_y)
df_testy = pd.DataFrame(df_test_y)

# %%
df_total_y = pd.concat([dfy, df_testy], axis=0)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(
    df_total_x , df_total_y,
    test_size=0.20, random_state=20)

# %%
rf3 = rfc(n_estimators = 200, oob_score=True, n_jobs = -1, random_state = 123)
rf3.fit(x_train,y_train)
print(f'Estimated accuracy with OOB data: {rf3.oob_score_:.4f}')
print(f'Training data accuracy: {rf3.score(x_train,y_train):.4f}')
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Estimated accuracy with OOB data: 0.8135
# Training data accuracy: 0.9562

# %%
print(f'Test dataset accuracy: {rf2.score(x_test, y_test): .4f}')
# Out:
# Test dataset accuracy:  0.9086

# %%
test_preds2 = rf3.predict(x_test)
test_preds2
# Out:
# array([1, 0, 1, ..., 0, 1, 0])

# %%
x_test.iloc[99]
# Out:
# Age                                       24
# EducationNum                               9
# HoursPerWeek                              40
# CapitalGain                                0
# Female                                     1
# CapitalLoss                                0
# MaritalStatus_Divorced                 False
# MaritalStatus_Married-AF-spouse        False
# MaritalStatus_Married-civ-spouse       False
# MaritalStatus_Married-spouse-absent    False
# MaritalStatus_Never-married             True
# MaritalStatus_Separated                False
# MaritalStatus_Widowed                  False
# Occupation_Adm-clerical                False
# Occupation_Armed-Forces                False
# Occupation_Craft-repair                False
# Occupation_Exec-managerial             False
# Occupation_Farming-fishing             False
# Occupation_Handlers-cleaners            True
# Occupation_Machine-op-inspct           False
# Occupation_Other-service               False
# Occupation_Priv-house-serv             False
# Occupation_Prof-specialty              False
# Occupation_Protective-serv             False
# Occupation_Sales                       False
# Occupation_Tech-support                False
# Occupation_Transport-moving            False
# Name: 2791, dtype: object

# %%
test_preds2[99]
# Out:
# np.int64(0)

# %%
y_test.iloc[99]
# Out:
# 0    0
# Name: 2791, dtype: int64

# %%
test_preds2[99] == y_test.iloc[99]
# Out:
# 0    True
# Name: 2791, dtype: bool

# %% [markdown]
# Exercise #3: Train a logistic regression model to predict the label using just age, educationnum, and capitalgain (call it lr).  Don't forget to scale the features.  You can use the same train_test split from Exercise 2.
#
# What is the accuracy on the test data set?
# What are the features for the 200th row of the test dataset and what is the prediction? Is it accurate?
#
# Compute and display a confusion matrix similar to how we did so previously in this worksheet for random forest.

# %%
lr_features = df[['Age','EducationNum', 'CapitalGain']]

x_train, x_test, y_train, y_test = train_test_split(
    lr_features , df['Label'],
    test_size=0.20, random_state=42)

scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)


lr = LogisticRegression()
lr.fit(x_train_scaled,y_train)
lr.score(x_test_scaled,y_test)
# Out:
# 0.7200399467376831

# %%
x_test.iloc[199]
# Out:
# Age             35
# EducationNum    10
# CapitalGain      0
# Name: 251, dtype: int64

# %%
test_preds3 = lr.predict(x_test_scaled)
test_preds3
# Out:
# array(['>50K', '<=50K', '<=50K', ..., '<=50K', '>50K', '>50K'],
#       dtype=object)

# %%
y_test
# Out:
# 8402      >50K
# 708      <=50K
# 476      <=50K
# 7936      >50K
# 149      <=50K
#          ...
# 5344     <=50K
# 6466     <=50K
# 6685     <=50K
# 13150     >50K
# 14468     >50K
# Name: Label, Length: 3004, dtype: object

# %%
test_preds3[199] == y_test.iloc[199]
# Out:
# True

# %%
print(f'Test dataset accuracy: {lr.score(x_test, y_test): .4f}')
cm = confusion_matrix(y_test,test_preds3)
cmd = ConfusionMatrixDisplay(cm,display_labels = label_encoder.classes_)
cmd.plot()
# Out:
# Test dataset accuracy:  0.4980
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(

# %% [markdown]
# Exercise #4: Let's turn this on its head and try to predict gender from some of the other features using the random forest (call it rf4). Use Age, EducationNum, HoursPerWeek and CapitalGain.
#
# Then calculate the OOB accuracy as well as the accuracy on the test data set.
#
# What are the features for the 300th row of the test dataset and what is the prediction?  Is it accurate?
#
# Compute and display a confusion matrix.

# %%
features = df[['Age','EducationNum', 'HoursPerWeek','CapitalGain']]

x_train, x_test, y_train, y_test = train_test_split(
    features , df['Female'],
    test_size=0.20, random_state=42)

# %%
rf4 = rfc(n_estimators = 200, oob_score=True, n_jobs = -1, random_state = 123)
rf4.fit(x_train,y_train)
print(f'Estimated accuracy with OOB data: {rf4.oob_score_:.4f}')
print(f'Training data accuracy: {rf4.score(x_train,y_train):.4f}')
# Out:
# Estimated accuracy with OOB data: 0.7164
# Training data accuracy: 0.8415

# %%
label_encoder = LabelEncoder()
rf4_y = label_encoder.fit_transform(df['Female'])
print(label_encoder.classes_)
print(rf4_y)
# Out:
# [0 1]
# [1 0 0 ... 0 0 0]

# %%
df_test['Female'] = df_test['Sex'].map({'Female':1, 'Male':0})
df_test_x = pd.get_dummies(df_test[x], prefix = x_cat, columns = x_cat)
df_test_x
# Out:
#       Age  EducationNum  HoursPerWeek  CapitalGain  Female  CapitalLoss  \
# 0      32            13            40            0       1            0
# 1      34            10            32            0       0            0
# 2      20            10            40            0       0            0
# 3      36             4            35            0       0            0
# 4      73             9            35            0       1            0
# ...   ...           ...           ...          ...     ...          ...
# 7395   28            15            50            0       0            0
# 7396   56             9            40            0       0            0
# 7397   41            15            45            0       0            0
# 7398   37            14            40            0       0            0
# 7399   48            13            38            0       1            0
#
#       MaritalStatus_Divorced  MaritalStatus_Married-AF-spouse  \
# 0                      False                            False
# 1                      False                            False
# 2                      False                            False
# 3                      False                            False
# 4                       True                            False
# ...                      ...                              ...
# 7395                   False                            False
# 7396                   False                            False
# 7397                   False                            False
# 7398                   False                            False
# 7399                   False                            False
#
#       MaritalStatus_Married-civ-spouse  MaritalStatus_Married-spouse-absent  \
# 0                                False                                False
# 1                                 True                                False
# 2                                False                                False
# 3                                 True                                False
# 4                                False                                False
# ...                                ...                                  ...
# 7395                              True                                False
# 7396                              True                                False
# 7397                              True                                False
# 7398                              True                                False
# 7399                             False                                False
#
#       ...  Occupation_Farming-fishing  Occupation_Handlers-cleaners  \
# 0     ...                       False                         False
# 1     ...                       False                          True
# 2     ...                       False                          True
# 3     ...                        True                         False
# 4     ...                       False                         False
# ...   ...                         ...                           ...
# 7395  ...                       False                         False
# 7396  ...                       False                         False
# 7397  ...                       False                         False
# 7398  ...                       False                         False
# 7399  ...                       False                         False
#
#       Occupation_Machine-op-inspct  Occupation_Other-service  \
# 0                            False                     False
# 1                            False                     False
# 2                            False                     False
# 3                            False                     False
# 4                            False                     False
# ...                            ...                       ...
# 7395                         False                     False
# 7396                         False                     False
# 7397                         False                     False
# 7398                         False                     False
# 7399                         False                     False
#
#       Occupation_Priv-house-serv  Occupation_Prof-specialty  \
# 0                          False                       True
# 1                          False                      False
# 2                          False                      False
# 3                          False                      False
# 4                          False                      False
# ...                          ...                        ...
# 7395                       False                       True
# 7396                       False                      False
# 7397                       False                       True
# 7398                       False                      False
# 7399                       False                      False
#
#       Occupation_Protective-serv  Occupation_Sales  Occupation_Tech-support  \
# 0                          False             False                    False
# 1                          False             False                    False
# 2                          False             False                    False
# 3                          False             False                    False
# 4                          False             False                    False
# ...                          ...               ...                      ...
# 7395                       False             False                    False
# 7396                       False             False                    False
# 7397                       False             False                    False
# 7398                       False             False                    False
# 7399                       False              True                    False
#
#       Occupation_Transport-moving
# 0                           False
# 1                           False
# 2                           False
# 3                           False
# 4                           False
# ...                           ...
# 7395                        False
# 7396                        False
# 7397                        False
# 7398                        False
# 7399                        False
#
# [7400 rows x 27 columns]

# %%
df_test_y = label_encoder.transform(df_test['Female'])

# %%
test_preds4 = rf4.predict(x_test)

# %%
print(f'Test dataset accuracy: {rf4.score(x_test, y_test): .4f}')
# Out:
# Test dataset accuracy:  0.7150

# %%
test_preds4[299]
# Out:
# np.int64(1)

# %%
y_test.iloc[299]
# Out:
# np.int64(0)

# %%
test_preds4[299] == y_test.iloc[299]
# Out:
# np.False_

# %%
cm = confusion_matrix(y_test,test_preds4)
cmd = ConfusionMatrixDisplay(cm,display_labels = label_encoder.classes_)
cmd.plot()
